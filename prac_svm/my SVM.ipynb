# %% [markdown]
# # Results & Answers

# %%
# set system path
import sys
sys.path.insert(0, '../prac_svm')

# %%
# import all libraries
from my_svm import linear_svm
from my_svm import apply_one_svm
from my_svm import grid_search
from my_svm import rbf_svm_best_para

# %%
# run the first SVM classifier with linear kernel
linear_svm(1) # error penalty == 1
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy:  0.8

# %%
# change the error penalty to a larger value
linear_svm(100)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy:  0.8

# %%
# change the error penalty to a even larger value
linear_svm(10000)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy:  0.8

# %% [markdown]
# With larger C parameters, the SVM classifier tends to choose a decision boundary with a small margin and it gives a better decision boundary when compared with small C parameters (large margins)

# %%
apply_one_svm('linear')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy for linear 0.8

# %%
apply_one_svm('poly')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy for poly 0.8
# /home/zzh/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
apply_one_svm('rbf')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.67      0.40      0.50         5
#            2       0.50      0.75      0.60         4
#
#    micro avg       0.73      0.73      0.73        15
#    macro avg       0.72      0.72      0.70        15
# weighted avg       0.76      0.73      0.73        15
#
# Overall accuracy for rbf 0.73

# %%
bestG, bestC = grid_search()
rbf_svm_best_para(bestG, bestC)
# Out:
# Grid scores on development set
# --only mean higher than .80 will be printed
#
# 0.815 (+/-0.237) for {'C': 0.125, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.815 (+/-0.255) for {'C': 0.125, 'gamma': 1.0, 'kernel': 'rbf'}
# 0.815 (+/-0.227) for {'C': 0.125, 'gamma': 2.0, 'kernel': 'rbf'}
# 0.807 (+/-0.235) for {'C': 0.25, 'gamma': 0.25, 'kernel': 'rbf'}
# 0.830 (+/-0.263) for {'C': 0.25, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.822 (+/-0.255) for {'C': 0.5, 'gamma': 0.25, 'kernel': 'rbf'}
# 0.822 (+/-0.267) for {'C': 0.5, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.822 (+/-0.267) for {'C': 1.0, 'gamma': 0.125, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 2.0, 'gamma': 0.0625, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 4.0, 'gamma': 0.03125, 'kernel': 'rbf'}
# 0.815 (+/-0.257) for {'C': 4.0, 'gamma': 0.0625, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 8.0, 'gamma': 0.015625, 'kernel': 'rbf'}
# 0.815 (+/-0.257) for {'C': 8.0, 'gamma': 0.03125, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 16.0, 'gamma': 0.0078125, 'kernel': 'rbf'}
# 0.807 (+/-0.255) for {'C': 16.0, 'gamma': 0.015625, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 32.0, 'gamma': 0.00390625, 'kernel': 'rbf'}
# 0.807 (+/-0.255) for {'C': 32.0, 'gamma': 0.0078125, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 64.0, 'gamma': 0.001953125, 'kernel': 'rbf'}
# 0.807 (+/-0.255) for {'C': 64.0, 'gamma': 0.00390625, 'kernel': 'rbf'}
# 0.815 (+/-0.250) for {'C': 128.0, 'gamma': 0.0009765625, 'kernel': 'rbf'}
# 0.807 (+/-0.255) for {'C': 128.0, 'gamma': 0.001953125, 'kernel': 'rbf'}
# 0.807 (+/-0.255) for {'C': 256.0, 'gamma': 0.0009765625, 'kernel': 'rbf'}
#
# Best parameters set found on development set
#
# {'C': 0.25, 'gamma': 0.5, 'kernel': 'rbf'}
#
# The best parameters are: gramma:  -1.0  and Cost:  -2.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      0.60      0.67         5
#            2       0.60      0.75      0.67         4
#
#    micro avg       0.80      0.80      0.80        15
#    macro avg       0.78      0.78      0.78        15
# weighted avg       0.81      0.80      0.80        15
#
# Overall accuracy for the best-parameter RBF SVM 0.8 the parameter gamma -1.000000, C -2.000000
# /home/zzh/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
