# %% [markdown]
# # Results & Answers

# %%
# set system path
import sys
sys.path.insert(0, '../prac_svm')

# ignore the deprecation warnings
def warn(*args, **kwarges):
    pass
import warnings
warnings.warn = warn

# %%
# import all libraries
from my_svm import linear_svm
from my_svm import apply_one_svm
from my_svm import grid_search
from my_svm import rbf_svm_best_para

# %%
# run the first SVM classifier with linear kernel
linear_svm(1) # error penalty == 1
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy:  0.93

# %%
# change the error penalty to a larger value
linear_svm(100)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy:  0.93

# %%
# change the error penalty to a even larger value
linear_svm(10000)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy:  0.93

# %% [markdown]
# With larger C (cost) parameters, the SVM classifier tends to choose a decision boundary with a small margin and it gives a better decision boundary when compared with small C parameters (large margins)

# %%
apply_one_svm('linear')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy for linear 0.93

# %%
apply_one_svm('poly')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy for poly 0.93

# %%
apply_one_svm('rbf')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# Overall accuracy for rbf 0.93

# %%
bestG, bestC = grid_search()
rbf_svm_best_para(bestG, bestC)
# Out:
# Grid scores on development set
# --only mean higher than .80 will be printed
#
# 0.807 (+/-0.226) for {'C': 0.0625, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.815 (+/-0.238) for {'C': 0.0625, 'gamma': 1.0, 'kernel': 'rbf'}
# 0.807 (+/-0.262) for {'C': 0.125, 'gamma': 1.0, 'kernel': 'rbf'}
# 0.815 (+/-0.238) for {'C': 0.25, 'gamma': 0.5, 'kernel': 'rbf'}
#
# Best parameters set found on development set
#
# {'C': 0.0625, 'gamma': 1.0, 'kernel': 'rbf'}
#
# The best parameters are: gramma:  0.0  and Cost:  -4.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.80      1.00      0.89         4
#            2       1.00      0.75      0.86         4
#
#    micro avg       0.93      0.93      0.93        15
#    macro avg       0.93      0.92      0.92        15
# weighted avg       0.95      0.93      0.93        15
#
# ...
